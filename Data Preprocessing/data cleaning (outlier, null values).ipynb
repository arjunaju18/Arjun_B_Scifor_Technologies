# %%
import pandas as pd
import numpy as np

# %%
data = {
    'name': ['Arun', 'Alice', 'Bob', 'Justin', 'Afin', 'Jacks', 'Musk'],
    'income': [5000, 6000, 4000, 7500, 8000, 7000, 10000000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name    income
# 0    Arun      5000
# 1   Alice      6000
# 2     Bob      4000
# 3  Justin      7500
# 4    Afin      8000
# 5   Jacks      7000
# 6    Musk  10000000

# %%
df.describe()
# Out:
#              income
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
df.income
# Out:
# 0        5000
# 1        6000
# 2        4000
# 3        7500
# 4        8000
# 5        7000
# 6    10000000
# Name: income, dtype: int64

# %%
df.income.quantile(0.45)
# Out:
# 6700.0

# %%
df.income.quantile(0.75)
# Out:
# 7750.0

# %%
df.income.quantile(1)
# Out:
# 10000000.0

# %%
percentile_99 = df.income.quantile(0.99)
percentile_99
# Out:
# 9400479.999999994

# %%
df_no_outlier = df[df.income<=percentile_99]
df_no_outlier
# Out:
#      name  income
# 0    Arun    5000
# 1   Alice    6000
# 2     Bob    4000
# 3  Justin    7500
# 4    Afin    8000
# 5   Jacks    7000

# %%
df
# Out:
#      name    income
# 0    Arun      5000
# 1   Alice      6000
# 2     Bob      4000
# 3  Justin      7500
# 4    Afin      8000
# 5   Jacks      7000
# 6    Musk  10000000

# %%
df['income'][3]=np.NaN
# Out:
# C:\Users\Ajupo\AppData\Local\Temp\ipykernel_27256\3054271026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income'][3]=np.NaN

# %%
df_no_outlier
# Out:
#      name      income
# 0    Arun      5000.0
# 1   Alice      6000.0
# 2     Bob      4000.0
# 3  Justin         NaN
# 4    Afin      8000.0
# 5   Jacks      7000.0
# 6    Musk  10000000.0

# %%
df.income.mean()
# Out:
# 1671666.6666666667

# %%
df_new = df.fillna(df.income.mean())
df_new
# Out:
#      name        income
# 0    Arun  5.000000e+03
# 1   Alice  6.000000e+03
# 2     Bob  4.000000e+03
# 3  Justin  1.671667e+06
# 4    Afin  8.000000e+03
# 5   Jacks  7.000000e+03
# 6    Musk  1.000000e+07

# %%
df_new = df.fillna(df.income.median())
df_new
# Out:
#      name      income
# 0    Arun      5000.0
# 1   Alice      6000.0
# 2     Bob      4000.0
# 3  Justin      6500.0
# 4    Afin      8000.0
# 5   Jacks      7000.0
# 6    Musk  10000000.0

# %%
df = pd.read_csv("C:/Users/Ajupo/Downloads/AB_NYC_2019.csv")

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df.price
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
df['price'].isnull().sum()
# Out:
# 0

# %%
df.price.quantile([0.01, 0.999])
# Out:
# 0.010      30.0
# 0.999    3000.0
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01, 0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price>min_thresold) & (df.price<max_thresold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                               name    host_id  \
# 20390  16274292   Large studio apt in brownstone w/ private garden  106437594
# 10806   8321236                  Conveniently Located Brooklyn Apt    4818113
# 42359  32870169             Spacious 1 Bedroom in the West Village   60668386
# 26779  21256268  Cozy, Elegant & Spacious Studio in Upper East ...    1819910
# 46991  35533850   Your Own Private  Hideaway Junior Suite in Soho!  264478123
#
#               host_name neighbourhood_group    neighbourhood  latitude  \
# 20390             Lance           Manhattan          Chelsea  40.74586
# 10806           Veralyn            Brooklyn      Brownsville  40.66780
# 42359           Madison           Manhattan     West Village  40.73341
# 26779            Andrew           Manhattan  Upper East Side  40.77398
# 46991  The Broome Hotel           Manhattan             SoHo  40.72109
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
